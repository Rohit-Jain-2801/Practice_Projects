# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 12, 7

from apyori import apriori

# import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %% [markdown]
# ## Converting dataset into the form needed by the algorithm

# %%
# Algorithm needs list of lists
transactions = []
for i in range(0, df.shape[0]):
    transactions.append([str(df.values[i,j]) for j in range(0, df.shape[1])])

# %%
transactions[0]
# Out:
# ['shrimp',
#  'almonds',
#  'avocado',
#  'vegetables mix',
#  'green grapes',
#  'whole weat flour',
#  'yams',
#  'cottage cheese',
#  'energy drink',
#  'tomato juice',
#  'low fat yogurt',
#  'green tea',
#  'honey',
#  'salad',
#  'mineral water',
#  'salmon',
#  'antioxydant juice',
#  'frozen smoothie',
#  'spinach',
#  'olive oil']

# %% [markdown]
# ## Apriori

# %% [markdown]
# <pre>
# Let X,Y be itemsets, X->Y an association rule and T a set of transactions of a given database.
#
# Support
#     It is an indication of how frequently the itemset appears in the dataset.
#     supp(Y) = (No. of appearance of 'Y')/(Total no. of transactions)
#
# Confidence
#     It is an indication of how often the rule has been found to be true.
#     conf(X->Y) = (No. of appearance of 'X & Y')/(No. of appearance of 'X')
#     conf(X->Y) = supp(X&Y)/supp(X)
#
# Lift
#     It is the ratio of the observed support to that expected if X and Y were independent.
#     lift(X->Y) = conf(X->Y)/supp(Y)
#     lift = 1 => no rule can be drawn (independent)
#     lift > 1 => positive effect
#     lift < 1 => negative effect
#
# Conviction
#     It can be interpreted as the ratio of the expected frequency that X occurs without Y.
#     It is the frequency that the rule makes an incorrect prediction.
#     conv(X->Y) = (1-supp(Y))/(1-conf(X->Y))
#
# Rule Power Factor (RPF)
#     It is an indication of how intense a rule’s items are associated with each other in terms of positive relationship.
#     It is the measure of importance.
#     rpf(X->Y) = conf(X->Y)*supp(X&Y)
# </pre>

# %%
# from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
results = list(rules)

# %%
results[0]
# Out:
# RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)])

# %%
dt = pd.DataFrame(columns=['Item_Base','Item_Add','Support','Confidence','Lift'], dtype=object)

# %%
for i in range(len(results)):
    dt.at[i,'Item_Base'] = list(results[i][2][0][0])
    dt.at[i,'Item_Add'] = list(results[i][2][0][1])
    dt.at[i,'Support'] = results[i][1]
    dt.at[i,'Confidence'] = results[i][2][0][2]
    dt.at[i,'Lift'] = results[i][2][0][3]

# %%
dt
# Out:
#                                              Item_Base             Item_Add  \
# 0                                        [light cream]            [chicken]
# 1                               [mushroom cream sauce]           [escalope]
# 2                                              [pasta]           [escalope]
# 3                                      [fromage blanc]              [honey]
# 4                                      [herb & pepper]        [ground beef]
# 5                                       [tomato sauce]        [ground beef]
# 6                                        [light cream]          [olive oil]
# 7                                  [whole wheat pasta]          [olive oil]
# 8                                              [pasta]             [shrimp]
# 9                                 [spaghetti, avocado]               [milk]
# 10                                        [cake, milk]            [burgers]
# 11                                 [turkey, chocolate]            [burgers]
# 12                                      [turkey, milk]            [burgers]
# 13                           [frozen vegetables, cake]           [tomatoes]
# 14                              [ground beef, cereals]          [spaghetti]
# 15                              [chicken, ground beef]               [milk]
# 16                                  [nan, light cream]            [chicken]
# 17                                     [chicken, milk]          [olive oil]
# 18                                [chicken, spaghetti]          [olive oil]
# 19                      [frozen vegetables, chocolate]             [shrimp]
# 20                          [herb & pepper, chocolate]        [ground beef]
# 21                                   [soup, chocolate]               [milk]
# 22                          [cooking oil, ground beef]          [spaghetti]
# 23                                 [eggs, ground beef]      [herb & pepper]
# 24                                    [red wine, eggs]          [spaghetti]
# 25                         [nan, mushroom cream sauce]           [escalope]
# 26                                        [pasta, nan]           [escalope]
# 27                         [french fries, ground beef]      [herb & pepper]
# 28                                [fromage blanc, nan]              [honey]
# 29                      [green tea, frozen vegetables]           [tomatoes]
# ..                                                 ...                  ...
# 124                             [spaghetti, nan, milk]          [olive oil]
# 125                              [nan, tomatoes, milk]               [soup]
# 126                [nan, whole wheat pasta, spaghetti]               [milk]
# 127                         [nan, soup, mineral water]          [olive oil]
# 128            [nan, whole wheat pasta, mineral water]          [olive oil]
# 129                         [pancakes, nan, spaghetti]          [olive oil]
# 130                         [olive oil, nan, tomatoes]          [spaghetti]
# 131                 [nan, whole wheat rice, spaghetti]           [tomatoes]
# 132              [mineral water, eggs, nan, chocolate]        [ground beef]
# 133  [mineral water, nan, frozen vegetables, chocol...        [ground beef]
# 134   [ground beef, nan, frozen vegetables, chocolate]          [spaghetti]
# 135  [mineral water, nan, frozen vegetables, chocol...               [milk]
# 136     [spaghetti, nan, frozen vegetables, chocolate]               [milk]
# 137  [mineral water, nan, frozen vegetables, chocol...             [shrimp]
# 138         [spaghetti, mineral water, nan, chocolate]          [olive oil]
# 139         [spaghetti, mineral water, nan, chocolate]             [shrimp]
# 140      [eggs, nan, frozen vegetables, mineral water]               [milk]
# 141   [spaghetti, nan, frozen smoothie, mineral water]               [milk]
# 142  [ground beef, nan, frozen vegetables, mineral ...               [milk]
# 143        [ground beef, nan, frozen vegetables, milk]          [spaghetti]
# 144  [spaghetti, nan, frozen vegetables, mineral wa...        [ground beef]
# 145      [mineral water, nan, frozen vegetables, milk]          [olive oil]
# 146      [mineral water, nan, frozen vegetables, milk]               [soup]
# 147              [spaghetti, mineral water, nan, milk]  [frozen vegetables]
# 148  [spaghetti, nan, frozen vegetables, mineral wa...             [shrimp]
# 149  [spaghetti, nan, frozen vegetables, mineral wa...           [tomatoes]
# 150         [spaghetti, olive oil, nan, mineral water]        [ground beef]
# 151        [ground beef, nan, tomatoes, mineral water]          [spaghetti]
# 152              [spaghetti, mineral water, nan, milk]          [olive oil]
# 153              [spaghetti, mineral water, nan, milk]           [tomatoes]
#
#         Support Confidence     Lift
# 0    0.00453273   0.290598  4.84395
# 1    0.00573257   0.300699  3.79083
# 2    0.00586588   0.372881  4.70081
# 3    0.00333289   0.245098  5.16427
# 4     0.0159979    0.32345  3.29199
# 5    0.00533262   0.377358  3.84066
# 6    0.00319957   0.205128  3.11471
# 7    0.00799893   0.271493  4.12241
# 8    0.00506599   0.322034  4.50667
# 9    0.00333289   0.416667  3.21545
# 10   0.00373284       0.28  3.21144
# 11   0.00306626   0.270588  3.10349
# 12   0.00319957   0.282353  3.23842
# 13   0.00306626   0.298701  4.36756
# 14   0.00306626   0.676471   3.8853
# 15   0.00386615   0.408451  3.15205
# 16   0.00453273   0.290598  4.84395
# 17   0.00359952   0.243243  3.69346
# 18    0.0034662    0.20155  3.06038
# 19   0.00533262   0.232558  3.25451
# 20   0.00399947   0.441176  4.49018
# 21   0.00399947   0.394737  3.04622
# 22   0.00479936   0.571429    3.282
# 23   0.00413278   0.206667  4.17845
# 24   0.00373284   0.528302   3.0343
# 25   0.00573257   0.300699  3.79083
# 26   0.00586588   0.372881  4.70081
# 27   0.00319957   0.230769  4.66577
# 28   0.00333289   0.245098  5.16427
# 29   0.00333289   0.231481  3.38468
# ..          ...        ...      ...
# 124  0.00719904   0.203008  3.08251
# 125  0.00306626   0.219048  4.33529
# 126  0.00399947   0.454545  3.50776
# 127  0.00519931   0.225434  3.42303
# 128  0.00386615   0.402778  6.11586
# 129  0.00506599   0.201058  3.05291
# 130  0.00439941   0.611111  3.50991
# 131  0.00306626   0.216981  3.17266
# 132  0.00399947    0.29703  3.02309
# 133  0.00333289   0.342466  3.48553
# 134  0.00306626   0.534884   3.0721
# 135  0.00399947   0.410959   3.1714
# 136   0.0034662   0.440678  3.40075
# 137  0.00319957   0.328767   4.6009
# 138  0.00386615   0.243697  3.70035
# 139   0.0034662   0.218487   3.0576
# 140  0.00373284   0.411765  3.17762
# 141  0.00319957   0.470588  3.63157
# 142  0.00373284   0.405797  3.13157
# 143  0.00306626   0.534884   3.0721
# 144  0.00439941   0.366667  3.73184
# 145  0.00333289   0.301205  4.57356
# 146  0.00306626   0.277108  5.48441
# 147  0.00453273   0.288136   3.0228
# 148  0.00333289   0.277778  3.88733
# 149  0.00306626   0.255556  3.73669
# 150  0.00306626   0.298701  3.04011
# 151  0.00306626   0.560976  3.22196
# 152  0.00333289   0.211864  3.21699
# 153  0.00333289   0.211864  3.09785
#
# [154 rows x 5 columns]
